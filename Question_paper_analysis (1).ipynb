# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
df.shape
# Out:
# (86, 12)

# %%
df=df.fillna(0)
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6
# 0       4      6
# 1       0      0
# 2       0      0
# 3       2      0
# ...

# %%
df=df.astype("int64")

# %%
df=df.fillna(0)

# %%
df["Q1"] = df["Q1aM4"] + df["Q1bM6"]
df["Q2"] = df["Q2aM6"] + df["Q2bM4"]
df["Q3"] = df["Q3aM5"] + df["Q3bM5"]
df["Q4"] = df["Q4aM3"] + df["Q4bM7"]
df["Q5"] = df["Q5M10"]
df["Q6"] = df["Q6aM4"] + df["Q6bM6"]

# %%
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6  Q1  Q2  Q3  Q4  Q5  Q6
# 0       4      6   9  10   3   5   8  10
# ...

# %%
df.drop(["Q1aM4","Q1bM6","Q2aM6","Q2bM4","Q3aM5","Q3bM5","Q4aM3","Q4bM7","Q5M10","Q6aM4","Q6bM6"],axis=1, inplace=True)
df
# Out:
#     Total  Q1  Q2  Q3  Q4  Q5  Q6
# 0      37   9  10   3   5   8  10
# 1      32   7   7   0   9   9   0
# 2      33   9   6  10   0   8   0
# 3      24  10   9   4   0   0   2
# 4      36   9   8   9   0  10   0
# ..    ...  ..  ..  ..  ..  ..  ..
# 81     32   9   7   8   0   0  10
# 82     27   4   8   0   0   7   8
# 83     37  10   8   0   0   9  10
# 84     28   4   9   9   0   6   0
# 85     29  10   0   0   8   7   5
#
# [86 rows x 7 columns]

# %%
df=df.fillna(0)

# %%
df.plot()
plt.show()

# %%
plt.hist(df['Q1'],color='purple',edgecolor='black',bins=9)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %%
df.plot.scatter(x = 'Q1', y ='Total',color='red',s=40)
plt.title("Scatter plot for Q1")
# Out:
# Text(0.5, 1.0, 'Scatter plot for Q1')

# %%
df.boxplot(by='Q4',column =['Total'], grid = False,color='black')
plt.title("Boxplot of Q4")
plt.ylabel("Total")
plt.show()

# %%
n = pd.DataFrame({'1.1': [10, 20, 30]}, index=['A', 'B', 'C'])
n['1.1'].plot(kind='pie',figsize=(8,8))
plt.title("piechart of marks in Q5")
plt.show()

# %%
plt.figure(figsize=(10, 6))  # Increase figure size
plt.plot(df["Q2"], marker='o', linestyle='-', color='b')
plt.title("Trend of Q2 Marks", fontsize=14)
plt.xlabel("Student Index", fontsize=12)
plt.ylabel("Total Marks", fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.grid(True)  
plt.show()

# %%
plt.figure(figsize=(12, 6))
df.iloc[:, 1:].head(10).plot(kind="bar", stacked=True, colormap="viridis", ax=plt.gca())
plt.title("Stacked Bar Chart (First 10 Students)", fontsize=14)
plt.xlabel("Student Index", fontsize=12)
plt.ylabel("Marks", fontsize=12)
plt.xticks(rotation=360)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap of Score Correlations", fontsize=14)
plt.xticks(rotation=360, ha="right", fontsize=10)
plt.yticks(rotation=0, fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.fill_between(range(len(df)), df["Total"].cumsum(), color='cyan', alpha=0.5)
plt.plot(df["Total"].cumsum(), marker='o', linestyle='-', color='blue', alpha=0.7)
plt.title("Cumulative Sum of Total Marks", fontsize=14)
plt.xlabel("Student Index", fontsize=12)
plt.ylabel("Cumulative Marks", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %% [markdown]
# import seaborn as sns
# plt.figure(figsize=(8, 5))
# sns.kdeplot(df["Total"], color='magenta', fill=True)
# plt.title("Density Plot of Total Marks", fontsize=14)
# plt.xlabel("Total Marks", fontsize=12)
# plt.ylabel("Density", fontsize=12)
# plt.grid(True, linestyle="--", alpha=0.6)
# plt.show()

# %%
import numpy as np
plt.figure(figsize=(8, 5))

questions = ["Q1", "Q2", "Q3", "Q4", "Q5", "Q6"]
means = df[questions].mean()
std_devs = df[questions].std()

plt.errorbar(questions, means, yerr=std_devs, fmt='o', color='red', capsize=5, markersize=8, linewidth=2)
plt.title("Mean & Standard Deviation of Each Question", fontsize=14)
plt.xlabel("Questions", fontsize=12)
plt.ylabel("Mean Score", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.show()
