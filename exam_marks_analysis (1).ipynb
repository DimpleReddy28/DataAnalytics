# %% [markdown]
# Name : Y.BHAVANA

# %% [markdown]
# Roll NO: 2211CS010602

# %% [markdown]
# Section: GROUP-3 Sem Id: G-3(64)

# %% [markdown]
# DA CASE STUDY- 2 ON MIDMARKS DATASET

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
df = pd.read_excel("MIDMARKS.xlsx")
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %% [markdown]
# This is the midmarks dataset of students

# %%
df.shape
# Out:
# (718, 8)

# %% [markdown]
# This is the shape of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  691 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %% [markdown]
# This is the info of the midmarks dataset

# %%
columns_to_include = [col for col in df.columns if col != "S.NO"]
summary_stats = df[columns_to_include].describe()
print(summary_stats)
# Out:
#                DV        M-II          PP        BEEE          FL        FIMS
# count  705.000000  704.000000  701.000000  697.000000  702.000000  694.000000
# mean    15.018440   10.119318   13.042796   13.649928   15.854701   14.492795
# std      4.211517    6.524925    5.567600    5.422731    3.938757    4.052588
# min      1.000000    0.000000    0.000000    0.000000    1.000000    0.000000
# 25%     12.000000    4.000000    9.000000   10.000000   13.000000   12.000000
# 50%     16.000000   10.000000   14.000000   15.000000   16.000000   15.000000
# 75%     18.000000   16.000000   18.000000   18.000000   20.000000   18.000000
# max     20.000000   20.000000   20.000000   20.000000   20.000000   20.000000

# %% [markdown]
# This output summarizes six columns with their count, average (mean), spread (std), and range (min to max).
# It shows how data is distributed, with the mean, minimum and maximum values across columns.

# %%
df.head()
# Out:
#    S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0   1.0   ALPHA  12    0  17    9  19   15
# 1   2.0   ALPHA  19   12  16   16  18    3
# 2   3.0   ALPHA  18   14  18   18  18   16
# 3   4.0   ALPHA  15    9  19   17  19   15
# 4   5.0   ALPHA  18   17  19   19  20   18

# %% [markdown]
# Generally, df.head() displays the first few rows of a DataFrame, giving a quick overview of the
# data structure, including column names, data types, and initial values.

# %%
df.tail()
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19

# %% [markdown]
# The df.tail() function shows the last few rows of the DataFrame. It provides the structure of the
# dataset, including column names, data types, and the final entries.

# %%
df=df.fillna(0)

# %%
df.isnull().sum()
# Out:
# S.NO       0
# SECTION    0
# DV         0
# M-II       0
# PP         0
# BEEE       0
# FL         0
# FIMS       0
# dtype: int64

# %% [markdown]
# The df.isnull().sum() function calculates the number of missing (null) values in each column of the DataFrame.

# %%
df = df.dropna(subset=["DV"])
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df.dtypes
# Out:
# S.NO       float64
# SECTION     object
# DV          object
# M-II        object
# PP          object
# BEEE        object
# FL          object
# FIMS        object
# dtype: object

# %% [markdown]
# It gives the different datatypes present in the dataset

# %%
import numpy as np
df['S.NO'].astype(np.int64)
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 713    0
# 714    0
# 715    0
# 716    0
# 717    0
# Name: S.NO, Length: 718, dtype: int64

# %% [markdown]
# This is used to convert the data type of the column S.NO in the
# DataFrame(df) to a 64-bit integer format (int64).

# %%
df=df.fillna(0)
df['S.NO'] = df['S.NO'].astype(int)
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce').astype('Int64')

# %%
df["Total"] = df[["DV", "M-II", "PP", "BEEE", "FL", "FIMS"]].apply(pd.to_numeric, errors="coerce").sum(axis=1)

# %% [markdown]
# This code adds a new column Total to the DataFrame , representing the total score for each
# row across the specified numeric columns.

# %%
import pandas as pd

# Convert all columns except "SECTION" and "S.NO" to numeric, forcing errors to NaN
cols_to_convert = ["DV", "M-II", "PP", "BEEE", "FL", "FIMS"]
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors="coerce")

# Fill NaN values (optional: you can replace with 0 or mean)
df[cols_to_convert] = df[cols_to_convert].fillna(0).astype("int64")

# Check the new data types
print(df.dtypes)
# Out:
# S.NO       float64
# SECTION     object
# DV           int64
# M-II         int64
# PP           int64
# BEEE         int64
# FL           int64
# FIMS         int64
# Grade       object
# Total        int64
# dtype: object

# %%
df.dtypes
# Out:
# S.NO       float64
# SECTION     object
# DV           int64
# M-II         int64
# PP           int64
# BEEE         int64
# FL           int64
# FIMS         int64
# Grade       object
# Total        int64
# dtype: object

# %%
top_performers = df.nlargest(10, 'Total')
print("Top Performers:")
print(top_performers)
# Out:
# Top Performers:
#       S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS Grade  Total
# 505  506.0   OMEGA  20    20  20    20  20    20  None    120
# 507  508.0   OMEGA  20    20  20    20  20    20  None    120
# 574  575.0   SIGMA  20    20  20    20  20    20  None    120
# 596  597.0   SIGMA  20    20  20    20  20    20  None    120
# 251  252.0   DELTA  20    20  20    19  20    20  None    119
# 453  454.0   OMEGA  20    20  20    20  20    19  None    119
# 533  534.0   OMEGA  20    19  20    20  20    20  None    119
# 613    NaN     NaN  20    20  19    20  20    20  None    119
# 618    NaN     NaN  20    20  20    20  20    19  None    119
# 23    24.0   ALPHA  20    20  20    20  20    18  None    118

# %% [markdown]
# Identify and display the top performers based on total scores.

# %%
low_performers = df.nsmallest(20, 'Total')
print("Lowest Performers:")
print(low_performers)
# Out:
# Lowest Performers:
#       S.NO  SECTION  DV  M-II  PP  BEEE  FL  FIMS Grade  Total
# 244  245.0    DELTA   0     0   0     0   0     0  None      0
# 336  337.0  EPSILON   0     0   0     0   0     0  None      0
# 402  403.0    GAMMA   0     0   0     0   0     0  None      0
# 414  415.0    GAMMA   0     0   0     0   0     0  None      0
# 495  496.0    OMEGA   0     0   0     0   0     0  None      0
# 551  552.0    SIGMA   0     0   0     0   0     0  None      0
# 556  557.0    SIGMA   0     0   0     0   0     0  None      0
# 650    NaN     ZETA   0     0   0     0   0     0  None      0
# 82    83.0    ALPHA   2     0   2     0   0     0  None      4
# 673    NaN     ZETA   2     0   0     0   2     1  None      5
# 487  488.0    OMEGA   1     5   0     0   0     0  None      6
# 458  459.0    OMEGA   6     1   0     0   0     0  None      7
# 450  451.0    OMEGA   9     0   0     0   0     0  None      9
# 503  504.0    OMEGA   1     1   2     0  10     0  None     14
# ...

# %% [markdown]
# Identify and display the lowest-performing students based on total

# %%
df["Grade"] = None  
df.loc[df["Total"] > 110, "Grade"] = "First"
df.loc[(df["Total"] <= 110) & (df["Total"] > 80), "Grade"] = "Second"
df.loc[(df["Total"] <= 80) & (df["Total"] > 60), "Grade"] = "Third"
df.loc[(df["Total"] <= 60) & (df["Total"] >= 30), "Grade"] = "Pass"
df.loc[(df["Total"] < 30) & (df["Total"] >= 0), "Grade"] = "Fail"
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS   Grade  Total
# 0     1.0   ALPHA  12     0  17     9  19    15   Third     72
# 1     2.0   ALPHA  19    12  16    16  18     3  Second     84
# 2     3.0   ALPHA  18    14  18    18  18    16  Second    102
# 3     4.0   ALPHA  15     9  19    17  19    15  Second     94
# 4     5.0   ALPHA  18    17  19    19  20    18   First    111
# ..    ...     ...  ..   ...  ..   ...  ..   ...     ...    ...
# 713   NaN    ZETA  19     8   8    19  17    18  Second     89
# 714   NaN    ZETA  12     1   7    10  20     8    Pass     58
# 715   NaN    ZETA  17     6  14    14  17    18  Second     86
# 716   NaN    ZETA  12     1   6     7  15    12    Pass     53
# 717   NaN    ZETA  19    14  17    16  20    19  Second    105
#
# [716 rows x 10 columns]

# %% [markdown]
# This code modifies a DataFrame by adding a new column, Grade based on conditions applied to another column Total.
# This logic creates a grading system based on ranges of scores in the Total column.

# %%
df['Result'] = df['Total'].apply(lambda x: 'pass' if x>=30 else 'Fail')
result_count=df['Result'].value_counts()
print("Pass and Fail Count:")
print(result_count)
# Out:
# Pass and Fail Count:
# Result
# pass    690
# Fail     26
# Name: count, dtype: int64

# %% [markdown]
# The result count for the Pass and Fail categories provides a breakdown of how many
# students passed or failed based on their total marks.

# %%
subjects = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
average_scores = {s: df[s].mean() for s in subjects}
highest_avg_subject = max(average_scores, key=average_scores.get)
print(f"Question with the highest average score: {highest_avg_subject}")
# Out:
# Question with the highest average score: FL

# %% [markdown]
# This code determines which subject has the highest average score among the six subjects
# (DV, M-II, PP, BEEE, FL, and FIMS) in the DataFrame df. It calculates the mean scores
# for each subject, finds the subject with the highest average.

# %%
df['Percentage'] = (df['Total'] / df['Total'].max()) * 100
print(df[['Total', 'Percentage']])
# Out:
#      Total  Percentage
# 0       72   60.000000
# 1       84   70.000000
# 2      102   85.000000
# 3       94   78.333333
# 4      111   92.500000
# ..     ...         ...
# 713     89   74.166667
# 714     58   48.333333
# 715     86   71.666667
# 716     53   44.166667
# 717    105   87.500000
#
# [716 rows x 2 columns]

# %% [markdown]
# This calculates the percentage of each student's total score relative to the
# maximum total score in the dataset and adds it as a new column called Percentage.

# %%
equal_scores = df[df['DV'] == df['PP']]
print("Students with equal scores in DV and PP:")
print(equal_scores)
# Out:
# Students with equal scores in DV and PP:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS   Grade  Total Result  \
# 2     3.0   ALPHA  18    14  18    18  18    16  Second    102   pass
# 11   12.0   ALPHA  20    20  20    20  19    16   First    115   pass
# 23   24.0   ALPHA  20    20  20    20  20    18   First    118   pass
# 30   31.0   ALPHA  11    12  11     3  13     6    Pass     56   pass
# 39   40.0   ALPHA  20    17  20    19  20    18   First    114   pass
# ..    ...     ...  ..   ...  ..   ...  ..   ...     ...    ...    ...
# 650   NaN    ZETA   0     0   0     0   0     0    Fail      0   Fail
# 664   NaN    ZETA  15    12  15    14  17     9  Second     82   pass
# 668   NaN    ZETA  17    19  17    18  20    18  Second    109   pass
# 678   NaN    ZETA   9     5   9    13  14    12   Third     62   pass
# 695   NaN    ZETA  15     8  15    17  20    19  Second     94   pass
#
#      Percentage
# 2     85.000000
# 11    95.833333
# 23    98.333333
# ...

# %% [markdown]
# This code filters the students who have equal scores in two subjects: DV and PP.
# It then prints out the details of these students.

# %%
std_devs = {s: df[s].std() for s in subjects}
print("Standard deviation for each subject:")
print(std_devs)
# Out:
# Standard deviation for each subject:
# {'DV': 4.569545254964489, 'M-II': 6.599236016826634, 'PP': 5.817381269518226, 'BEEE': 5.783111636550407, 'FL': 4.476132482775705, 'FIMS': 4.709814997162521}

# %% [markdown]
# This calculates the standard deviation for each subject listed in the subjects list and prints
# the result.Standard deviation measures the amount of variation or dispersion of scores within each subject.

# %%
def performance_category(total):
    if total >= 110:
        return "Excellent"
    elif total >= 80:
        return "Good"
    elif total >= 50:
        return "Average"
    else:
        return "Poor"
df['Performance'] = df['Total'].apply(performance_category)
print(df[['Total', 'Performance']])
# Out:
#      Total Performance
# 0       72     Average
# 1       84        Good
# 2      102        Good
# 3       94        Good
# 4      111   Excellent
# ..     ...         ...
# 713     89        Good
# 714     58     Average
# 715     86        Good
# 716     53     Average
# 717    105        Good
#
# [716 rows x 2 columns]

# %% [markdown]
# This code defines a function that categorizes a student's performance based on their
# total score and adds a new column Performance to the df to store the corresponding
# performance category for each student.

# %%
top_students = df.sort_values(by='Total', ascending=False).head(5)
print("Top 5 students based on total marks:")
print(top_students)
# Out:
# Top 5 students based on total marks:
#       S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Grade  Total Result  \
# 507  508.0   OMEGA  20    20  20    20  20    20  First    120   pass
# 505  506.0   OMEGA  20    20  20    20  20    20  First    120   pass
# 574  575.0   SIGMA  20    20  20    20  20    20  First    120   pass
# 596  597.0   SIGMA  20    20  20    20  20    20  First    120   pass
# 618    NaN     NaN  20    20  20    20  20    19  First    119   pass
#
#      Percentage Performance
# 507  100.000000   Excellent
# 505  100.000000   Excellent
# 574  100.000000   Excellent
# 596  100.000000   Excellent
# 618   99.166667   Excellent

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["DV"], bins=20, color="skyblue", kde=True)
plt.title("Histogram of Numerical Column")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=df[cols_to_convert], palette="plasma")
plt.title("Violin Plot of Subject Marks")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["DV"], y=df["M-II"], color="red")
plt.title("Scatter Plot of DV vs M-II")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df[cols_to_convert], palette="coolwarm")
plt.title("Boxplot of Subject Marks")
plt.show()

# %%
plt.figure(figsize=(8, 5))
df[cols_to_convert].mean().plot(kind='bar', color='purple')
plt.title("Mean Marks of Each Subject")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x=df.index, y=df["Total"], marker="o", color="blue")
plt.title("Line Plot of Total Marks")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(df[cols_to_convert].corr(), annot=True, cmap="coolwarm")
plt.title("Heatmap of Subject Correlations")
plt.show()

# %%
bplt.figure(figsize=(8, 5))
sns.kdeplot(df["Total"], shade=True, color="green")
plt.title("KDE Plot of Total Marks")
plt.show()
# Out:
# C:\Users\GangiReddy\AppData\Local\Temp\ipykernel_24492\511627765.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["Total"], shade=True, color="green")

# %%
plt.figure(figsize=(8, 5))
df.nlargest(5, "Total")["Total"].plot.pie(autopct="%1.1f%%", colors=sns.color_palette("pastel"))
plt.title("Top 5 Students' Total Marks Distribution")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.swarmplot(data=df[cols_to_convert], palette="husl")
plt.title("Swarm Plot of Subject Marks")
plt.show()
# Out:
# C:\Users\GangiReddy\anakonda\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 68.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\GangiReddy\anakonda\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 61.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\GangiReddy\anakonda\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 62.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\GangiReddy\anakonda\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 63.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(8, 5))
sns.stripplot(data=df[cols_to_convert], jitter=True, palette="Accent")
plt.title("Strip Plot of Subject Marks")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxenplot(data=df[cols_to_convert], palette="magma")
plt.title("Boxen Plot of Subject Marks")
plt.show()
